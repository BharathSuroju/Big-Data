# %%
ACCESS_KEY  = 'AKIASE7ZJRTXHT3RCVY5'
SECRET_KEY  = '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'
BUCKET_NAME = 'data-engineer-training'
sc._jsc.hadoopConfiguration().set("fs.s3n.awsAccessKeyId", ACCESS_KEY)
sc._jsc.hadoopConfiguration().set("fs.s3n.awsSecretAccessKey", SECRET_KEY)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
rawRdd =  sc.textFile("s3://%s/data/card_transactions.json" % BUCKET_NAME)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#Getting the total amount spent by each user
import json
def getdictionaryvalues(inputrecord):
  dictionary= {}
  dictionary = json.loads(inputrecord)
  if dictionary['ts'] >= 1580515200 and dictionary['ts']< 1583020800 :
    return (dictionary['user_id'],dictionary['amount'])
rawRdd2 = rawRdd.map(getdictionaryvalues).filter(lambda x: x is not None)
rawRdd3 = rawRdd2.reduceByKey(lambda x,y : x+y)
rawRdd2.take(2)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[4]: [(&#39;U_103&#39;, 699), (&#39;U_101&#39;, 855)]</div>

# %%
#Get the total amount spent by each user for each of their cards
def getdictionaryvalues(inputrecord):
  dictionary= {}
  dictionary = json.loads(inputrecord)
  if dictionary['ts'] >= 1580515200 and dictionary['ts']< 1583020800 :
    return ((dictionary['user_id'],dictionary['card_num']),dictionary['amount'])
rawRdd2 = rawRdd.map(getdictionaryvalues).filter(lambda x: x is not None)
rawRdd3 = rawRdd2.reduceByKey(lambda x,y : x+y)
rawRdd2.collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[5]: [((&#39;U_103&#39;, &#39;C_106&#39;), 699),
#  ((&#39;U_101&#39;, &#39;C_101&#39;), 855),
#  ((&#39;U_104&#39;, &#39;C_107&#39;), 87),
#  ((&#39;U_104&#39;, &#39;C_107&#39;), 576),
#  ((&#39;U_103&#39;, &#39;C_105&#39;), 240),
#  ((&#39;U_101&#39;, &#39;C_101&#39;), 496),
#  ((&#39;U_102&#39;, &#39;C_103&#39;), 980),
#  ((&#39;U_102&#39;, &#39;C_103&#39;), 622),
#  ((&#39;U_103&#39;, &#39;C_104&#39;), 810),
#  ((&#39;U_102&#39;, &#39;C_103&#39;), 981),
#  ((&#39;U_102&#39;, &#39;C_103&#39;), 364),
#  ((&#39;U_104&#39;, &#39;C_107&#39;), 693),
#  ((&#39;U_101&#39;, &#39;C_101&#39;), 481),
# ...

# %%
#Get the total amount spend by each user for each of their cards on each category
def getdictionaryvalues(inputrecord):
  dictionary= {}
  dictionary = json.loads(inputrecord)
  if dictionary['ts'] >= 1580515200 and dictionary['ts']< 1583020800 :
    return ((dictionary['user_id'],dictionary['card_num'],dictionary['category']),dictionary['amount'])
rawRdd2 = rawRdd.map(getdictionaryvalues).filter(lambda x: x is not None)
rawRdd3 = rawRdd2.reduceByKey(lambda x,y : x+y)
rawRdd3.collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[6]: [((&#39;U_103&#39;, &#39;C_106&#39;, &#39;cosmetics&#39;), 3828),
#  ((&#39;U_103&#39;, &#39;C_105&#39;, &#39;groceries&#39;), 3902),
#  ((&#39;U_103&#39;, &#39;C_105&#39;, &#39;cosmetics&#39;), 5870),
#  ((&#39;U_103&#39;, &#39;C_105&#39;, &#39;food&#39;), 3157),
#  ((&#39;U_103&#39;, &#39;C_106&#39;, &#39;children&#39;), 6412),
#  ((&#39;U_104&#39;, &#39;C_108&#39;, &#39;entertainment&#39;), 5497),
#  ((&#39;U_103&#39;, &#39;C_106&#39;, &#39;entertainment&#39;), 3587),
#  ((&#39;U_104&#39;, &#39;C_108&#39;, &#39;cosmetics&#39;), 5163),
#  ((&#39;U_103&#39;, &#39;C_106&#39;, &#39;food&#39;), 5297),
# ...

# %%
#Get the distinct list of categories in which the user has made expenditure
def getdictionaryvalues(inputrecord):
  dictionary= {}
  dictionary = json.loads(inputrecord)
  if dictionary['ts'] >= 1580515200 and dictionary['ts']< 1583020800 :
    return (dictionary['user_id'],dictionary['category'])
rawRdd2 = rawRdd.map(getdictionaryvalues).filter(lambda x: x is not None)
rawRdd3 = rawRdd2.groupByKey().map(lambda x :(x[0],set(list(x[1]))))
rawRdd3.collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[45]: [(&#39;U_101&#39;, {&#39;children&#39;, &#39;cosmetics&#39;, &#39;entertainment&#39;, &#39;food&#39;, &#39;groceries&#39;}),
#  (&#39;U_102&#39;, {&#39;children&#39;, &#39;cosmetics&#39;, &#39;entertainment&#39;, &#39;food&#39;, &#39;groceries&#39;}),
#  (&#39;U_103&#39;, {&#39;children&#39;, &#39;cosmetics&#39;, &#39;entertainment&#39;, &#39;food&#39;, &#39;groceries&#39;}),
#  (&#39;U_104&#39;, {&#39;children&#39;, &#39;cosmetics&#39;, &#39;entertainment&#39;, &#39;food&#39;, &#39;groceries&#39;})]</div>

# %%
#Get the category in which the user has made the maximum expenditure
def getdictionaryvalues(inputrecord):
  dictionary= {}
  dictionary = json.loads(inputrecord)
  if dictionary['ts'] >= 1580515200 and dictionary['ts']< 1583020800 :
    return ((dictionary['user_id'],dictionary['category']),dictionary['amount'])
rawRdd2 = rawRdd.map(getdictionaryvalues).filter(lambda x: x is not None)
rawRdd3 = rawRdd2.reduceByKey(lambda x,y:x+y)
def getsortvalues(inputrecord):
  return (inputrecord[0][0],(inputrecord[0][1],inputrecord[1]))
rawRdd4 = rawRdd3.map(getsortvalues)
rawRdd5 = rawRdd4.groupByKey().map(lambda x :(x[0],(sorted(x[1], key = lambda x: x[1],reverse = True))[0]))
rawRdd5.collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[25]: [(&#39;U_101&#39;, (&#39;entertainment&#39;, 16104)),
#  (&#39;U_102&#39;, (&#39;entertainment&#39;, 16927)),
#  (&#39;U_103&#39;, (&#39;entertainment&#39;, 14522)),
#  (&#39;U_104&#39;, (&#39;food&#39;, 12253))]</div>
